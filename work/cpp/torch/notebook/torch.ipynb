// %%
#pragma cling add_include_path("/work/work/thirdparty/libtorch/include")
#pragma cling add_include_path("/work/work/thirdparty/libtorch/include/torch/csrc/api/include")
#pragma cling add_library_path("/work/work/thirdparty/libtorch/lib")
#pragma cling load("libtorch")

// %%
#include <iostream>
#include <torch/torch.h>
#include <ATen/ATen.h>
#include <torch/csrc/autograd/variable.h>
#include <torch/csrc/autograd/function.h>
// Out:
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:4:2: error: C++17 or later compatible compiler is required to use PyTorch.
// #error C++17 or later compatible compiler is required to use PyTorch.
//  ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:11:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Device.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Exception.h:5:
// /work/work/thirdparty/libtorch/include/c10/macros/Macros.h:175:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::cuda {}
//              ^~~~~~
//               { namespace cuda }
// /work/work/thirdparty/libtorch/include/c10/macros/Macros.h:176:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::hip {}
//              ^~~~~
//               { namespace hip }
// /work/work/thirdparty/libtorch/include/c10/macros/Macros.h:177:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::xpu {}
//              ^~~~~
//               { namespace xpu }
// /work/work/thirdparty/libtorch/include/c10/macros/Macros.h:189:13: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace at::cuda {
//             ^~~~~~
//              { namespace cuda
// /work/work/thirdparty/libtorch/include/c10/macros/Macros.h:201:13: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace at::cuda {
//             ^~~~~~
//              { namespace cuda
// /work/work/thirdparty/libtorch/include/c10/macros/Macros.h:205:13: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace at::xpu {
//             ^~~~~
//              { namespace xpu
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:11:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Device.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Exception.h:8:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/StringUtil.h:6:
// /work/work/thirdparty/libtorch/include/c10/util/string_view.h:580:27: error: no template named 'basic_string_view' in namespace 'std'; did you mean simply 'basic_string_view'?
//   using std_string_type = ::std::basic_string_view<CharT>;
//                           ^~~~~~~~~~~~~~~~~~~~~~~~
//                           basic_string_view
// /work/work/thirdparty/libtorch/include/c10/util/string_view.h:29:7: note: 'basic_string_view' declared here
// class basic_string_view final {
//       ^
// /work/work/thirdparty/libtorch/include/c10/util/string_view.h:605:29: error: no template named 'basic_string_view' in namespace 'std'; did you mean 'at::basic_string_view'?
//     using std_string_type = ::std::basic_string_view<CharT>;
//                             ^~~~~~~~~~~~~~~~~~~~~~~~
//                             at::basic_string_view
// /work/work/thirdparty/libtorch/include/c10/util/string_view.h:29:7: note: 'at::basic_string_view' declared here
// class basic_string_view final {
//       ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:11:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Device.h:5:
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:122:34: error: no template named 'variant' in namespace 'std'
//   using warning_variant_t = std::variant<UserWarning, DeprecationWarning>;
//                             ~~~~~^
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:125:7: error: unknown type name 'warning_variant_t'
//       warning_variant_t type,
//       ^
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:131:7: error: unknown type name 'warning_variant_t'
//       warning_variant_t type,
//       ^
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:137:7: error: unknown type name 'warning_variant_t'
//       warning_variant_t type,
//       ^
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:143:3: error: unknown type name 'warning_variant_t'
//   warning_variant_t type() const;
//   ^
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:150:3: error: unknown type name 'warning_variant_t'
//   warning_variant_t type_;
//   ^
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:453:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::detail {
//              ^~~~~~~~
//               { namespace detail
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:482:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::detail {
//              ^~~~~~~~
//               { namespace detail
// /work/work/thirdparty/libtorch/include/c10/util/Exception.h:649:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::detail {
//              ^~~~~~~~
//               { namespace detail
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeTraits.h:6:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::guts {
//              ^~~~~~
//               { namespace guts
// /work/work/thirdparty/libtorch/include/c10/util/TypeTraits.h:17:10: error: no template named 'void_t' in namespace 'std'; did you mean '__void_t'?
//     std::void_t<decltype(std::declval<T&>() == std::declval<T&>())>>
//     ~~~~~^~~~~~
//          __void_t
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:631:25: note: '__void_t' declared here
//   template<typename...> using __void_t = void;
//                         ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeTraits.h:28:28: error: no template named 'void_t' in namespace 'std'; did you mean '__void_t'?
// struct is_hashable<T, std::void_t<decltype(std::hash<T>()(std::declval<T&>()))>>
//                       ~~~~~^~~~~~
//                            __void_t
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:631:25: note: '__void_t' declared here
//   template<typename...> using __void_t = void;
//                         ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeTraits.h:104:13: error: no template named 'is_same_v' in namespace 'std'; did you mean 'is_same'?
//       !std::is_same_v<LambdaType, LambdaType>,
//        ~~~~~^~~~~~~~~
//             is_same
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1394:12: note: 'is_same' declared here
//     struct is_same
//            ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeTraits.h:104:46: error: expected '(' for function-style cast or type construction
//       !std::is_same_v<LambdaType, LambdaType>,
//        ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^
// /work/work/thirdparty/libtorch/include/c10/util/TypeTraits.h:140:14: error: no template named 'is_same_v' in namespace 'std'; did you mean 'is_same'?
//         std::is_same_v<bool, std::remove_cv_t<decltype(C<int>::value)>>>>
//         ~~~~~^~~~~~~~~
//              is_same
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1394:12: note: 'is_same' declared here
//     struct is_same
//            ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeTraits.h:140:9: error: template argument for non-type template parameter must be an expression
//         std::is_same_v<bool, std::remove_cv_t<decltype(C<int>::value)>>>>
//         ^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2553:17: note: template parameter is declared here
//   template<bool _Cond, typename _Tp = void>
//                 ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:10:14: warning: nested namespace definition is a C++17 extension; define each namespace separately [-Wc++17-extensions]
// namespace c10::guts {
//              ^~~~~~
//               { namespace guts
// /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:177:27: error: no template named 'is_same_v' in namespace 'std'; did you mean 'is_same'?
//     std::enable_if_t<std::is_same_v<Head, Type>>> : std::true_type {};
//                      ~~~~~^~~~~~~~~
//                           is_same
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1394:12: note: 'is_same' declared here
//     struct is_same
//            ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:177:22: error: template argument for non-type template parameter must be an expression
//     std::enable_if_t<std::is_same_v<Head, Type>>> : std::true_type {};
//                      ^~~~~~~~~~~~~~~~~~~~~~~~~~
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:2553:17: note: template parameter is declared here
//   template<bool _Cond, typename _Tp = void>
//                 ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:182:28: error: no template named 'is_same_v' in namespace 'std'; did you mean 'is_same'?
//     std::enable_if_t<!std::is_same_v<Head, Type>>>
//                       ~~~~~^~~~~~~~~
//                            is_same
// /usr/local/conda/bin/../lib/gcc/../../x86_64-conda-linux-gnu/include/c++/10.4.0/type_traits:1394:12: note: 'is_same' declared here
//     struct is_same
//            ^
// In file included from input_line_8:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/torch.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/all.h:7:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/api/include/torch/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/autograd.h:3:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/variable.h:6:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/cpp_hook.h:2:
// In file included from /work/work/thirdparty/libtorch/include/torch/csrc/autograd/function_hook.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/Tensor.h:3:
// In file included from /work/work/thirdparty/libtorch/include/ATen/core/TensorBody.h:12:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Layout.h:3:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/Backend.h:5:
// In file included from /work/work/thirdparty/libtorch/include/c10/core/DispatchKeySet.h:6:
// In file included from /work/work/thirdparty/libtorch/include/c10/util/Metaprogramming.h:3:
// /work/work/thirdparty/libtorch/include/c10/util/TypeList.h:182:49: error: expected '(' for function-style cast or type construction
//     std::enable_if_t<!std::is_same_v<Head, Type>>>
//                       ~~~~~~~~~~~~~~~~~~~~~~~~~~^
// <scratch space>:154:1: note: expanded from here
// >
// ^
// fatal error: too many errors emitted, stopping now [-ferror-limit=]
// The Kernel crashed while executing code in the current cell or a previous cell.
//
// Please review the code in the cell(s) to identify a possible cause of the failure.
//
// Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
//
// View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
